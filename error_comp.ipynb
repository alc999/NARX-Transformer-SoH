# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
Loss_log = np.load("./models_3_7/training_log_3_7.npy")

print(f"Train: {np.min(Loss_log[:,0])}, valid: {np.min(Loss_log[:,1])}")
# Out:
# Train: 0.002677792767062783, valid: 0.021263034939765932

# %%
Loss_log = np.load("./models_5_7/training_log_5_7.npy")

print(f"Train: {np.min(Loss_log[:,0])}, valid: {np.min(Loss_log[:,1])}")
# Out:
# Train: 0.0018172515119658783, valid: 0.011865765824913978

# %%
Loss_log = np.load("./models_7_7/training_log_7_7.npy")

print(f"Train: {np.min(Loss_log[:,0])}, valid: {np.min(Loss_log[:,1])}")
# Out:
# Train: 0.0017589441973320913, valid: 0.011623075200865666

# %%
best_epoch = np.argmin(Loss_log[:,1])

plt.figure(figsize=(8,4))
plt.plot(Loss_log[:, 0], linewidth=2.5)
plt.plot(Loss_log[:, 1], color='red', linewidth=1.5)
plt.legend(["Train Loss","Validation Loss"])
plt.grid("on")
plt.xlabel("Training Epoch", fontsize=15)
plt.ylabel("MAE Loss", fontsize=15)
plt.ylim([0, 0.1])
plt.show()
